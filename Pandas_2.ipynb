# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
hello = pd.read_excel('HR_Dataset_for_PowerBI_with_Errors.xlsx')
hello
# Out:
#    Employee ID Department  Hire Date Current Position  Salary (USD)  \
# 0        E0001         HR 2017-10-11           Senior        1530.0
# 1        E0002         IT 2018-10-04           Junior         570.0
# 2        E0003         IT 2019-12-24           Senior        1400.0
# 3        E0004      Sales 2021-07-12           Junior         760.0
# 4        E0005  Marketing 2021-07-31             Lead         800.0
# ..         ...        ...        ...              ...           ...
# 95       E0096    Finance 2021-08-11             Lead        1760.0
# 96       E0097         IT 2020-03-13          Manager        1880.0
# 97       E0098         IT 2016-11-20           Senior        1450.0
# 98       E0099  Logistics 2016-02-08              Mid        2070.0
# 99       E0100  Marketing 2016-01-21             Lead         880.0
#
#    Last Raise Date Position Changed New Position
# 0       2020-01-29               No       Senior
# 1       2020-01-31              Yes         Lead
# ...

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
hello.isnull().sum()
# Out:
# Employee ID         6
# Department          6
# Hire Date           5
# Current Position    7
# Salary (USD)        1
# Last Raise Date     7
# Position Changed    6
# New Position        6
# dtype: int64

# %%
hello.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Employee ID       94 non-null     object
#  1   Department        94 non-null     object
#  2   Hire Date         95 non-null     datetime64[ns]
#  3   Current Position  93 non-null     object
#  4   Salary (USD)      99 non-null     float64
#  5   Last Raise Date   93 non-null     datetime64[ns]
#  6   Position Changed  94 non-null     object
#  7   New Position      94 non-null     object
# dtypes: datetime64[ns](2), float64(1), object(5)
# memory usage: 6.4+ KB

# %%
hello.loc[19, 'Employee ID'] = 'E0020'
hello.loc[38, 'Employee ID'] = 'E0039'
hello.loc[65, 'Employee ID'] = 'E0066'
hello.loc[83, 'Employee ID'] = 'E0084'
hello.loc[89, 'Employee ID'] = 'E0090'
hello.loc[93, 'Employee ID'] = 'E0094'
hello
# Out:
#    Employee ID Department            Hire Date Current Position  Salary (USD)  \
# 0        E0001         HR  2017-10-11 00:00:00           Senior        1530.0
# 1        E0002         IT  2018-10-04 00:00:00           Junior         570.0
# 2        E0003         IT  2019-12-24 00:00:00           Senior        1400.0
# 3        E0004      Sales  2021-07-12 00:00:00           Junior         760.0
# 4        E0005  Marketing  2021-07-31 00:00:00             Lead         800.0
# 5        E0006  Marketing  2018-11-10 00:00:00           Senior         910.0
# 6        E0007         IT  2016-04-11 00:00:00              Mid         550.0
# 7        E0008    Finance  2015-02-18 00:00:00           Senior        2040.0
# 8        E0009  Marketing  2020-08-12 00:00:00           Senior        1140.0
# 9       E00010         IT  2019-05-21 00:00:00             Lead        2570.0
# 10       E0011  Logistics                 1961             Lead        2370.0
# ...

# %%
# Missing values to 'Manager'
hello['Current Position'] = hello['Current Position'].fillna('Manager')
hello
# Out:
#    Employee ID Department            Hire Date Current Position  Salary (USD)  \
# 0        E0001         HR  2017-10-11 00:00:00           Senior        1530.0
# 1        E0002         IT  2018-10-04 00:00:00           Junior         570.0
# 2        E0003         IT  2019-12-24 00:00:00           Senior        1400.0
# 3        E0004      Sales  2021-07-12 00:00:00           Junior         760.0
# 4        E0005  Marketing  2021-07-31 00:00:00             Lead         800.0
# 5        E0006  Marketing  2018-11-10 00:00:00           Senior         910.0
# 6        E0007         IT  2016-04-11 00:00:00              Mid         550.0
# 7        E0008    Finance  2015-02-18 00:00:00           Senior        2040.0
# 8        E0009  Marketing  2020-08-12 00:00:00           Senior        1140.0
# 9       E00010         IT  2019-05-21 00:00:00             Lead        2570.0
# 10       E0011  Logistics                 1961             Lead        2370.0
# ...

# %%
hello.loc[0, 'Salary (USD)'] = '$1000'
hello.loc[15, 'Salary (USD)'] = '$8000'
hello.loc[17, 'Salary (USD)'] = '$7000'
hello.loc[20, 'Salary (USD)'] = '$3000'
hello.loc[21, 'Salary (USD)'] = '$1000'
hello.loc[23, 'Salary (USD)'] = '$4500'
hello.loc[26, 'Salary (USD)'] = '$1400'
hello.loc[40, 'Salary (USD)'] = '$7900'
hello.loc[44, 'Salary (USD)'] = '$4760'
hello.loc[58, 'Salary (USD)'] = '$2900'
hello.loc[83, 'Salary (USD)'] = '$4900'
hello.loc[89, 'Salary (USD)'] = '$41900'
hello.loc[9, 'Last Raise Date'] =  '2021-10-31'
hello.loc[16, 'Last Raise Date'] =  '2021-10-31'
hello.loc[21, 'Last Raise Date'] =  '2021-10-31'
hello.loc[28, 'Last Raise Date'] =  '2021-10-31'
hello.loc[51, 'Last Raise Date'] =  '2021-10-31'
hello.loc[54, 'Last Raise Date'] =  '2021-10-31'
hello.loc[65, 'Last Raise Date'] =  '2021-10-31'
hello.loc[89, 'Last Raise Date'] =  '2021-10-31'


hello
# Out:
#    Employee ID Department            Hire Date Current Position Salary (USD)  \
# 0        E0001         HR  2017-10-11 00:00:00           Senior        $1000
# 1        E0002         IT  2018-10-04 00:00:00           Junior        570.0
# 2        E0003         IT  2019-12-24 00:00:00           Senior       1400.0
# 3        E0004      Sales  2021-07-12 00:00:00           Junior        760.0
# 4        E0005  Marketing  2021-07-31 00:00:00             Lead        800.0
# 5        E0006  Marketing  2018-11-10 00:00:00           Senior        910.0
# 6        E0007         IT  2016-04-11 00:00:00              Mid        550.0
# 7        E0008    Finance  2015-02-18 00:00:00           Senior       2040.0
# 8        E0009  Marketing  2020-08-12 00:00:00           Senior       1140.0
# 9       E00010         IT  2019-05-21 00:00:00             Lead       2570.0
# 10       E0011  Logistics                 1961             Lead       2370.0
# ...

# %%
hello
